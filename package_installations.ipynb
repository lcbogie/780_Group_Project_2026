# %% [markdown]
# # Package Installation
# I used the code cells below to install packages to the virtual environment. I've commented out cells after they've been ran so that they aren't accidentally run again, but retained them for record-keeping purposes.
# --CB, 6/24

# %%
#pip install pandas
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
